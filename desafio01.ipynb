# %%
import pandas as pd
import matplotlib.pyplot as plt
dict_faturamento = {
    'data_ref': [
        '2023-01-01', 
        '2020-02-01', 
        '2021-03-01', 
        '2022-04-01', 
        '2023-05-01',
        '2023-06-01', 
        '2020-07-01', 
        '2021-08-01', 
        '2022-09-01', 
        '2023-10-01',
        '2022-11-01', 
        '2023-12-01',
        ],
    'valor': [
        400000, 
        890000, 
        760000, 
        430000, 
        920000,
        340000, 
        800000, 
        500000, 
        200000, 
        900000,
        570000, 
        995000,
        ]
}

# %%
df_faturamento = pd.DataFrame.from_dict(dict_faturamento)

# %%
df_faturamento.valor.mean()
# Out:
# np.float64(642083.3333333334)

# %%
df_faturamento['data_ref'] = pd.to_datetime(df_faturamento['data_ref'])
df_faturamento['mes'] = df_faturamento['data_ref'].dt.month
df_faturamento
# Out:
#      data_ref   valor  mes
# 0  2023-01-01  400000    1
# 1  2020-02-01  890000    2
# 2  2021-03-01  760000    3
# 3  2022-04-01  430000    4
# 4  2023-05-01  920000    5
# 5  2023-06-01  340000    6
# 6  2020-07-01  800000    7
# 7  2021-08-01  500000    8
# 8  2022-09-01  200000    9
# 9  2023-10-01  900000   10
# 10 2022-11-01  570000   11
# 11 2023-12-01  995000   12

# %%
df_faturamento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   data_ref  12 non-null     datetime64[ns]
#  1   valor     12 non-null     int64
#  2   mes       12 non-null     int32
# dtypes: datetime64[ns](1), int32(1), int64(1)
# memory usage: 372.0 bytes

# %%
df_faturamento.sort_values('mes').plot.bar(x='mes', y='valor')
# Out:
# <Axes: xlabel='mes'>

# %%
df_faturamento.sort_values('mes').plot.line(x='mes', y='valor')
# Out:
# <Axes: xlabel='mes'>

# %%
df_faturamento.sort_values('data_ref').plot.bar(x='data_ref', y='valor')
# Out:
# <Axes: xlabel='data_ref'>

# %%
df_faturamento.sort_values('data_ref').plot.line(x='data_ref', y='valor')
# Out:
# <Axes: xlabel='data_ref'>
